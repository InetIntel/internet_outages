# %% [markdown]
# # Imports

# %%
import itertools

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %% [markdown]
# ## RIR data

# %%
rir = pd.read_csv("../data/rir.csv")

# %%
rir.head()
# Out:
#           Country  cc  cc3       rir
# 0     AFGHANISTAN  AF  AFG     APNIC
# 1         ALBANIA  AL  ALB  RIPE NCC
# 2         ALGERIA  DZ  DZA   AFRINIC
# 3  AMERICAN SAMOA  AS  ASM     APNIC
# 4         ANDORRA  AD  AND  RIPE NCC

# %% [markdown]
# ## state-owned ASes

# %%
soe = pd.read_csv("../data/soe/state_owned_ases.csv")
soe.head()
# Out:
#       asn conglomerate              org_id  \
# 0   18678       CO-IXA   @aut-18678-LACNIC
# 1  262195       CO-IXA  @aut-262195-LACNIC
# 2  262589       CO-IXA  @aut-262589-LACNIC
# 3   28032       CO-IXA   @aut-28032-LACNIC
# 4   52280       CO-IXA   @aut-52280-LACNIC
#
#                                             org_name ownership_cc  \
# 0                               INTERNEXA S.A. E.S.P           CO
# 1                Transamerican Telecomunication S.A.           CO
# 2  INTERNEXA BRASIL OPERADORA DE TELECOMUNICACOES...           CO
# 3                                 INTERNEXA PERU S.A           CO
# 4                               INTERNEXA Chile S.A.           CO
#
#   ownership_country_name     rir             source  \
# 0               Colombia  LACNIC  Company's website
# 1               Colombia  LACNIC  Company's website
# 2               Colombia  LACNIC  Company's website
# 3               Colombia  LACNIC  Company's website
# 4               Colombia  LACNIC  Company's website
#
#                                                quote quote_lang  \
# 0  Estructura accionaria. Gobierno colombiano: 51.41    Spanish
# 1  Estructura accionaria. Gobierno colombiano: 51.42    Spanish
# 2  Estructura accionaria. Gobierno colombiano: 51.43    Spanish
# 3  Estructura accionaria. Gobierno colombiano: 51.44    Spanish
# 4  Estructura accionaria. Gobierno colombiano: 51.45    Spanish
#
#                                                  url additional_info inputs  \
# 0  http://www.isa.co/es/nuestra-compania/Paginas/...             NaN   W, O
# 1  http://www.isa.co/es/nuestra-compania/Paginas/...             NaN   W, O
# 2  http://www.isa.co/es/nuestra-compania/Paginas/...             NaN   W, O
# 3  http://www.isa.co/es/nuestra-compania/Paginas/...             NaN   W, O
# 4  http://www.isa.co/es/nuestra-compania/Paginas/...             NaN   W, O
#
#        parent_org target_cc target_country_name
# 0             NaN       NaN                 NaN
# 1  CO-IESA-LACNIC        AR           Argentina
# 2  CO-IESA-LACNIC        BR              Brazil
# 3  CO-IESA-LACNIC        PE                Peru
# 4  CO-IESA-LACNIC        CL               Chile

# %% [markdown]
# ## Access network sizes

# %% [markdown]
# ### Geolocated address space

# %%
geoloc = pd.read_csv("../data/access-networks/geolocation_asn.csv")

# %%
geoloc.head()
# Out:
#       asn  cc   cc_frac
# 0     715  ZW  0.014205
# 1  327770  ZW  0.340922
# 2   36183  ZW  0.017756
# 3   34800  ZW  0.000222
# 4  328646  ZW  0.056820

# %% [markdown]
# ### APNIC eyeballs estimations

# %%
def remove_as_str(x):
    if str(x)[:2] == "AS":
        return int(float(str(x)[2:]))
    else: 
        return 0

# %%
eyeballs = pd.read_csv("../data/access-networks/2022_03_22.csv")
eyeballs["asn"] = eyeballs["asn"].map(remove_as_str)

# %% [markdown]
# # Social variables

# %%
social_vars = pd.read_csv("../data/polisci/politicalshutdowns_whoshutsdata_2018_2021.csv")

# %%
social_vars.head()
# Out:
#   Country.Code  year  totalshutdowns  nationalshutdowns  politicalshutdowns  \
# 0          ABW  2019               3                  3                   0
# 1          ABW  2020               1                  1                   0
# 2          AFG  2019               3                  3                   0
# 3          AFG  2020               3                  3                   0
# 4          AFG  2021               4                  1                   1
#
#    nationalpoliticalshutdowns      country           FDI           GDP  \
# 0                           0        Aruba -7.522654e+07  3.368970e+09
# 1                           0        Aruba  1.640876e+08  2.610039e+09
# 2                           0  Afghanistan  2.340455e+07  1.890449e+10
# 3                           0  Afghanistan  1.297015e+07  2.014344e+10
# 4                           0  Afghanistan  2.060098e+07  1.478686e+10
#
#    oilreserves_bbl  ...  nationalnonpoliticalshutdowns  nonpoliticalshutdowns  \
# 0              NaN  ...                              3                      3
# 1              NaN  ...                              1                      1
# 2              NaN  ...                              3                      3
# 3              NaN  ...                              3                      3
# 4              NaN  ...                              1                      3
#
#    shutdownind  national_shutdownind  regional_shutdownind  \
# 0         True                  True                 False
# 1         True                  True                 False
# 2         True                  True                 False
# 3         True                  True                 False
# 4         True                  True                  True
#
#    nationalpolitical_shutdownind  regionalpolitical_shutdownind  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                           True
#
#    political_shutdownind  nonpolitical_shutdownind  \
# 0                  False                      True
# 1                  False                      True
# 2                  False                      True
# 3                  False                      True
# 4                   True                      True
#
#    nationalnonpolitical_shutdownind
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
# [5 rows x 100 columns]

# %% [markdown]
# # Compute states' stake on the domestic access market

# %%
soe_geoloc = soe[["asn", "ownership_cc",]].join(
    geoloc[["asn", "cc", "cc_frac"]].set_index(["asn", "cc",]),
    on=["asn", "ownership_cc",],
    how='left',
    lsuffix='_matrix',
    rsuffix='_ingress'
)

soe_geoloc = soe_geoloc.dropna()

# %%
soe_geoloc.head()
# Out:
#       asn ownership_cc    cc_frac
# 0   18678           CO   0.815676
# 1  262195           CO   0.001239
# 2  262589           CO   0.110259
# 5   10269           BZ  52.086699
# 6    6568           BO  20.711639

# %%
soe_geoloc_addr = soe_geoloc.groupby("ownership_cc")["cc_frac"] \
    .sum() \
    .reset_index()

# %%
soe_geoloc_addr.head()
# Out:
#   ownership_cc    cc_frac
# 0           AD  90.376241
# 1           AE  91.292944
# 2           AF   9.291136
# 3           AG  21.120916
# 4           AO  20.581215

# %%
soe_geoloc_addr = rir[["cc", ]].join(
    soe_geoloc_addr.set_index(["ownership_cc",]),
    on=["cc",],
    how='left',
    lsuffix='_left',
    rsuffix='_right'
)

soe_geoloc_addr = soe_geoloc_addr.fillna(0)

# %%
soe_geoloc_addr.head()
# Out:
#    cc    cc_frac
# 0  AF   9.291136
# 1  AL   0.000000
# 2  DZ  96.272882
# 3  AS   0.000000
# 4  AD  90.376241

# %%
soe_geoloc_addr = soe_geoloc_addr.sort_values("cc_frac")
soe_geoloc_addr = soe_geoloc_addr.rename(columns = {'cc_frac':'soe_geoloc'})

# %% [markdown]
# ## Domestic footprint

# %%
soe_eyeballs = soe.drop_duplicates()[["asn", "ownership_cc",]].join(
    eyeballs.drop_duplicates()[["asn", "cc", "cc_frac"]].set_index(["asn", "cc",]),
    on=["asn", "ownership_cc",],
    how='left',
    lsuffix='_matrix',
    rsuffix='_ingress'
)

soe_eyeballs = soe_eyeballs.dropna()

# %%
soe_eyeballs.head()
# Out:
#       asn ownership_cc  cc_frac
# 0   18678           CO     0.90
# 2  262589           CO     0.89
# 5   10269           BZ    51.47
# 6    6568           BO    37.03
# 7   53237           BR     0.05

# %% [markdown]
# ### Fraction of the domestic eyeballs in state-owned networks

# %%
soe_eyeballs_addr = soe_eyeballs.groupby("ownership_cc")["cc_frac"] \
    .sum() \
    .reset_index()

# %%
soe_eyeballs_addr.head()
# Out:
#   ownership_cc  cc_frac
# 0           AD    98.54
# 1           AE    96.03
# 2           AF    13.70
# 3           AG    62.96
# 4           AO    15.69

# %% [markdown]
# I expand it to all countries and not just to the subset of countries with state-owned providers

# %%
soe_eyeballs_addr = rir[["cc", ]].join(
    soe_eyeballs_addr.set_index(["ownership_cc",]),
    on=["cc",],
    how='left',
    lsuffix='_left',
    rsuffix='_right'
)

soe_eyeballs_addr = soe_eyeballs_addr.fillna(0)

# %%
soe_eyeballs_addr.head()
# Out:
#    cc  cc_frac
# 0  AF    13.70
# 1  AL     0.00
# 2  DZ    87.14
# 3  AS     0.00
# 4  AD    98.54

# %%
soe_eyeballs_addr = soe_eyeballs_addr.sort_values("cc_frac")
soe_eyeballs_addr = soe_eyeballs_addr.rename(columns = {'cc_frac':'soe_eyeballs'})

# %% [markdown]
# # Augmented social variables

# %%
social_vars = rir[["cc", "cc3"]].join(
    social_vars.set_index(["Country.Code",]),
    on=["cc3",],
    how='left',
    lsuffix='_left',
    rsuffix='_right'
)

# %%
social_vars = social_vars.join(
    soe_geoloc_addr.set_index(["cc",]),
    on=["cc",],
    how='left',
    lsuffix='_left',
    rsuffix='_right'
)

# %%
social_vars = social_vars.join(
    soe_eyeballs_addr.set_index(["cc",]),
    on=["cc",],
    how='left',
    lsuffix='_left',
    rsuffix='_right'
)

# %%
social_vars.head()
# Out:
#    cc  cc3    year  totalshutdowns  nationalshutdowns  politicalshutdowns  \
# 0  AF  AFG  2019.0             3.0                3.0                 0.0
# 0  AF  AFG  2020.0             3.0                3.0                 0.0
# 0  AF  AFG  2021.0             4.0                1.0                 1.0
# 0  AF  AFG  2018.0             0.0                0.0                 0.0
# 1  AL  ALB  2019.0             1.0                0.0                 0.0
#
#    nationalpoliticalshutdowns      country           FDI           GDP  ...  \
# 0                         0.0  Afghanistan  2.340455e+07  1.890449e+10  ...
# 0                         0.0  Afghanistan  1.297015e+07  2.014344e+10  ...
# 0                         0.0  Afghanistan  2.060098e+07  1.478686e+10  ...
# 0                         0.0          NaN  1.194351e+08  1.841885e+10  ...
# 1                         0.0      Albania  1.201022e+09  1.540183e+10  ...
#
#    shutdownind  national_shutdownind  regional_shutdownind  \
# 0         True                  True                 False
# 0         True                  True                 False
# 0         True                  True                  True
# 0        False                 False                 False
# 1         True                 False                  True
#
#    nationalpolitical_shutdownind  regionalpolitical_shutdownind  \
# 0                          False                          False
# 0                          False                          False
# 0                          False                           True
# 0                          False                          False
# 1                          False                          False
#
#    political_shutdownind  nonpolitical_shutdownind  \
# 0                  False                      True
# 0                  False                      True
# 0                   True                      True
# 0                  False                     False
# 1                  False                      True
#
#    nationalnonpolitical_shutdownind  soe_geoloc  soe_eyeballs
# 0                              True    9.291136          13.7
# 0                              True    9.291136          13.7
# 0                              True    9.291136          13.7
# 0                             False    9.291136          13.7
# 1                             False    0.000000           0.0
#
# [5 rows x 103 columns]

# %% [markdown]
# I transform some continous into binary variables

# %%
social_vars["geoloc"] = social_vars["soe_geoloc"] > 50

# %%
social_vars["eyeballs"] = social_vars["soe_eyeballs"] > 50

# %%
social_vars["pms"] = social_vars["nationalpoliticalshutdowns"] > 0

# %%
social_vars["npms"] = (social_vars["nationalpoliticalshutdowns"] == 0) & (social_vars["nationalshutdowns"] > 0)

# %%
social_vars.groupby(["pms", "geoloc", "year"]).median()
# Out:
#                      totalshutdowns  nationalshutdowns  politicalshutdowns  \
# pms   geoloc year
# False False  2018.0             0.0                0.0                 0.0
#              2019.0             1.0                0.0                 0.0
#              2020.0             1.0                0.0                 0.0
#              2021.0             0.0                0.0                 0.0
#       True   2018.0             0.0                0.0                 0.0
#              2019.0             1.0                0.0                 0.0
#              2020.0             1.0                0.0                 0.0
#              2021.0             1.0                0.0                 0.0
# True  False  2018.0             3.0                3.0                 1.0
#              2019.0             8.0                5.0                 1.0
#              2020.0             2.0                1.5                 1.0
#              2021.0             5.0                3.0                 2.0
#       True   2018.0             9.0                3.0                 8.0
#              2019.0            12.5                6.0                 4.5
#              2020.0             6.5                3.0                 2.0
#              2021.0             3.0                2.0                 1.5
#
#                      nationalpoliticalshutdowns           FDI           GDP  \
# pms   geoloc year
# False False  2018.0                         0.0  6.487324e+08  2.631159e+10
#              2019.0                         0.0  9.580664e+08  3.263405e+10
#              2020.0                         0.0  4.640000e+08  2.587280e+10
#              2021.0                         0.0  9.218266e+08  2.873694e+10
#       True   2018.0                         0.0  3.960778e+08  2.421593e+10
#              2019.0                         0.0  3.404372e+08  2.430045e+10
#              2020.0                         0.0  1.582300e+08  1.799475e+10
#              2021.0                         0.0  1.667509e+08  2.103749e+10
# True  False  2018.0                         1.0  4.608905e+08  4.756821e+10
#              2019.0                         1.0  2.182079e+08  1.687441e+10
#              2020.0                         1.0  6.108697e+08  3.486380e+10
#              2021.0                         1.0  7.545517e+08  3.742792e+10
#       True   2018.0                         3.0  2.548710e+09  8.426935e+10
#              2019.0                         4.0  1.508000e+09  1.338398e+11
#              2020.0                         2.0  1.366800e+09  1.076580e+11
#              2021.0                         1.5  4.319874e+09  1.800780e+11
#
#                      oilreserves_bbl  oilprod_mt  oilprod_kbd  \
# pms   geoloc year
# False False  2018.0           2.9820   32.844000   674.420274
#              2019.0           3.1460   37.486737   774.786356
#              2020.0           2.8820   31.066370   631.925301
#              2021.0              NaN   32.370080   674.948707
#       True   2018.0          12.2000   54.943198  1165.205433
#              2019.0           4.4000   38.158677   780.661123
#              2020.0          14.8220   30.377058   628.288535
#              2021.0              NaN   29.666364   613.595146
# True  False  2018.0          73.2595  116.539282  2373.712971
#              2019.0           1.7500   19.668581   374.416984
#              2020.0           4.2500   19.078114   388.749660
#              2021.0              NaN   14.020331   274.000000
#       True   2018.0           2.5000    1.051034    24.051901
#              2019.0          12.2000   64.330000  1486.617014
#              2020.0           7.6000   30.641688   709.015431
#              2021.0              NaN   45.973334  1022.102068
#
#                      oilprod_ngl_kbd  ...      mobile  broadband   GDP_capita  \
# pms   geoloc year                     ...
# False False  2018.0        89.589549  ...  112.086661  12.969677  7833.195013
#              2019.0       100.389050  ...  111.387525  13.761164  8759.815064
#              2020.0        90.320432  ...  108.568713  15.245771  6863.074346
#              2021.0        82.041549  ...         NaN        NaN  8476.752157
#       True   2018.0        31.606806  ...  114.427861   9.683121  6839.323847
#              2019.0        27.386307  ...  115.210622   8.938324  7331.019211
#              2020.0        29.544399  ...  120.787155  10.459769  8287.730556
#              2021.0        39.575405  ...         NaN        NaN  6581.208412
# True  False  2018.0        64.386301  ...   80.841163   0.347671   720.265047
#              2019.0        33.863014  ...   85.940989   0.246701  1421.868596
#              2020.0        12.205601  ...   91.792966   1.494561  1057.878009
#              2021.0        70.019178  ...         NaN        NaN  1733.258675
#       True   2018.0         8.000000  ...   79.340313   3.913055  1104.392448
#              2019.0       247.413699  ...   97.303019   7.902363  2197.277421
#              2020.0       130.436612  ...   78.751803   4.331866  1322.315036
#              2021.0        21.506164  ...         NaN        NaN  4011.668580
#
#                      regionalshutdowns  nationalnonpoliticalshutdowns  \
# pms   geoloc year
# False False  2018.0                0.0                            0.0
#              2019.0                0.0                            0.0
#              2020.0                0.0                            0.0
#              2021.0                0.0                            0.0
#       True   2018.0                0.0                            0.0
#              2019.0                0.0                            0.0
#              2020.0                0.0                            0.0
#              2021.0                0.0                            0.0
# True  False  2018.0                0.0                            1.0
#              2019.0                0.0                            4.0
#              2020.0                0.0                            0.5
#              2021.0                0.5                            1.5
#       True   2018.0                5.0                            0.0
#              2019.0                0.5                            2.0
#              2020.0                1.0                            1.5
#              2021.0                0.0                            0.0
#
#                      nonpoliticalshutdowns  soe_geoloc  soe_eyeballs  \
# pms   geoloc year
# False False  2018.0                    0.0    0.000000         0.000
#              2019.0                    0.0    0.000000         0.000
#              2020.0                    1.0    0.000000         0.000
#              2021.0                    0.0    0.000000         0.000
#       True   2018.0                    0.0   77.050414        74.440
#              2019.0                    1.0   77.016866        74.120
#              2020.0                    1.0   76.190063        74.120
#              2021.0                    0.5   76.156515        74.435
# True  False  2018.0                    1.0    0.000000         0.000
#              2019.0                    6.0    2.900234         1.170
#              2020.0                    1.0    0.000000         0.000
#              2021.0                    2.0    2.043434         0.785
#       True   2018.0                    0.0   99.578414        96.280
#              2019.0                    2.0   97.925648        97.970
#              2020.0                    2.5   92.487545        91.710
#              2021.0                    0.5   97.870451        91.710
#
#                      eyeballs   npms
# pms   geoloc year
# False False  2018.0     False  False
#              2019.0     False  False
#              2020.0     False  False
#              2021.0     False  False
#       True   2018.0      True  False
#              2019.0      True  False
#              2020.0      True  False
#              2021.0      True  False
# True  False  2018.0     False  False
#              2019.0     False  False
#              2020.0     False  False
#              2021.0     False  False
#       True   2018.0      True  False
#              2019.0      True  False
#              2020.0      True  False
#              2021.0      True  False
#
# [16 rows x 90 columns]

# %%
#plt.rcParams["font.family"] = "Times New Roman"
fontsize=16

# %%
fig, _ax = plt.subplots(1, 2, figsize=(10, 5), sharex=True, sharey=True)


m = itertools.cycle(["o", "X", "^", "s"])

####

ax = _ax[0]

x = social_vars.loc[(social_vars["pms"] == True) & (social_vars["soe_geoloc"] > 0)]["soe_geoloc"]

ax.plot(
    np.sort(x) / 100,
    np.linspace(0, 1, len(x)),
    label="Shutdowns",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["npms"] == True) & (social_vars["soe_geoloc"] > 0)]["soe_geoloc"]

ax.plot(
    np.sort(x) / 100,
    np.linspace(0, 1, len(x)),
    label="Outages",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["totalshutdowns"] == 0) & (social_vars["soe_geoloc"] > 0)]["soe_geoloc"]

ax.plot(
    np.sort(x) / 100,
    np.linspace(0, 1, len(x)),
    label="Neither",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

ax.yaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')
ax.xaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')


# ax.set_title(v, fontsize=20)

ax.tick_params(labelsize=fontsize)

ax.set_xlabel("Frac. state-owned addr. space", fontsize=fontsize)
ax.set_ylabel("CDF", fontsize=fontsize)

ax.set_yticks(np.arange(0, 1.01, 0.25))

ax.legend(loc='lower right', ncol=1,
              frameon=True, fontsize=fontsize, handletextpad=0.25, columnspacing=0.5, 
              handlelength=1.5)

####
ax.tick_params(labelsize=fontsize)
ax = _ax[1]

x = social_vars.loc[(social_vars["pms"] == True) & (social_vars["soe_eyeballs"] > 0)]["soe_eyeballs"]

ax.plot(
    np.sort(x)  / 100,
    np.linspace(0, 1, len(x)),
    label="Shutdowns",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["npms"] == True) & (social_vars["soe_eyeballs"] > 0)]["soe_eyeballs"]

ax.plot(
    np.sort(x) / 100,
    np.linspace(0, 1, len(x)),
    label="Outages",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["totalshutdowns"] == 0) & (social_vars["soe_eyeballs"] > 0)]["soe_eyeballs"]

ax.plot(
    np.sort(x) / 100,
    np.linspace(0, 1, len(x)),
    label="Neither",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

ax.yaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')
ax.xaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')


# ax.set_title(v, fontsize=20)

ax.tick_params(labelsize=fontsize)

ax.set_xlabel("Frac. state-owned eyeballs", fontsize=fontsize)
# ax.set_ylabel("CDF", fontsize=20)

ax.set_yticks(np.arange(0, 1.01, 0.25))

ax.legend(loc='lower right', ncol=1,
              frameon=True, fontsize=fontsize, handletextpad=0.25, columnspacing=0.5, 
              handlelength=1.5)

        
fig.subplots_adjust(hspace=0)
fig.tight_layout()
fig.savefig("../figures/outage_scas.pdf")

# %%
fig, _ax = plt.subplots(1, 2, figsize=(10, 5), sharex=True, sharey=True)

m = itertools.cycle(["o", "X", "^", "s"])

v = "v2x_libdem"

####  

ax = _ax[0]

ax.yaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')
ax.xaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')


x = social_vars.loc[(social_vars["pms"] == True) & (social_vars["geoloc"] == False)][v]

ax.plot(
    np.sort(x),
    np.linspace(0, 1, len(x)),
    label="Shutdowns",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["npms"] == True) & (social_vars["geoloc"] == False) & (~social_vars[v].isnull())][v]

ax.plot(
    np.sort(x),
    np.linspace(0, 1, len(x)),
    label="Outages",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["totalshutdowns"] == 0) & (social_vars["geoloc"] == False) & (~social_vars[v].isnull())][v]

ax.plot(
    np.sort(x),
    np.linspace(0, 1, len(x)),
    label="Neither",
    marker=next(m),
    markevery = int(len(x) / 10),
    lw=2,
    markersize=10
)

ax.tick_params(labelsize=fontsize)

ax.set_title("Non state-controlled\naddr. space", fontsize=fontsize)
ax.set_xlabel("Liberal Democracy Score, V-Dem", fontsize=fontsize)
ax.set_ylabel("CDF", fontsize=fontsize)

ax.legend(loc='lower right', ncol=1, frameon=True, 
          fontsize=fontsize, handletextpad=0.25, 
          columnspacing=0.5, handlelength=1.5)

###

ax = _ax[1]

ax.yaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')
ax.xaxis.grid(True, linestyle='-', color='#bababa', alpha=0.5, which='both')


x = social_vars.loc[(social_vars["pms"] == True) 
                    & (social_vars["geoloc"] == True)
                    & (~social_vars[v].isnull())][v]

ax.plot(
    np.sort(x),
    np.linspace(0, 1, len(x)),
    label="Shutdowns",
    marker=next(m),
    markevery = int(len(x) / 10),
    color="C3",
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["npms"] == True) & (social_vars["geoloc"] == True) & (~social_vars[v].isnull())][v]

ax.plot(
    np.sort(x),
    np.linspace(0, 1, len(x)),
    label="Outages",
    marker=next(m),
    markevery = int(len(x) / 10),
    color="C4",
    lw=2,
    markersize=10
)

x = social_vars.loc[(social_vars["totalshutdowns"] == 0) & (social_vars["geoloc"] == True) & (~social_vars[v].isnull())][v]

ax.plot(
    np.sort(x),
    np.linspace(0, 1, len(x)),
    label="Neither",
    marker=next(m),
    markevery = int(len(x) / 10),
    color="C5",
    lw=2,
    markersize=10
)

ax.tick_params(labelsize=fontsize)
ax.set_xlabel("Liberal Democracy Score, V-Dem", fontsize=fontsize)
ax.set_title("State-controlled\naddr. space", fontsize=fontsize)

ax.legend(loc='lower right', ncol=1, frameon=True, 
          fontsize=fontsize, handletextpad=0.25, 
          columnspacing=0.5, handlelength=1.5)


###

#fig.suptitle("Liberal democracy index", fontsize=25)
        
fig.subplots_adjust(hspace=0)
fig.tight_layout()
fig.savefig("../figures/libdem_scas.pdf")

# %%
x = social_vars.loc[(social_vars["pms"] == True) & (social_vars["geoloc"] == False)][v]
y = social_vars.loc[(social_vars["pms"] == True) & (social_vars["geoloc"] == True)][v]

print("Average LibDem index")
print(f"PMS and SOE addr space > 50\%: {x.mean():.2f}")
print(f"PMS and SOE addr space < 50\%: {y.mean():.2f}")
print()
print("Median LibDem index")
print(f"PMS and SOE addr space > 50\%: {x.median():.2f}")
print(f"PMS and SOE addr space < 50\%: {y.median():.2f}")
print()
print("Std. LibDem index")
print(f"PMS and SOE addr space > 50\%: {x.std():.2f}")
print(f"PMS and SOE addr space < 50\%: {y.std():.2f}")
# Out:
# Average LibDem index
# PMS and SOE addr space > 50\%: 0.22
# PMS and SOE addr space < 50\%: 0.14
#
# Median LibDem index
# PMS and SOE addr space > 50\%: 0.21
# PMS and SOE addr space < 50\%: 0.14
#
# Std. LibDem index
# PMS and SOE addr space > 50\%: 0.13
# PMS and SOE addr space < 50\%: 0.09

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2b9a2535-ed0e-48ec-8277-3dc0993a1e10' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
